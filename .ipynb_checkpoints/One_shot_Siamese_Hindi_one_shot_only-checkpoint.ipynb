# %% [markdown]
# # Sentiment Analysis of IIT Patna Movie Reviews (in Hindi) using One shot learning

# %% [markdown]
# #### Dataset - https://github.com/AI4Bharat/indicnlp_corpus
#
# We use a One shot learning based approach in order to predict sentiments of Movie reviews in this dataset

# %% [markdown]
# ## From Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.10/dist-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.8.30)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.9.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=0aa0de21e65f10fbf6a2e8b2ca12d7dfce4c97eb2bfa28601721e506e833bd22
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: googletrans
#   Attempting uninstall: googletrans
#     Found existing installation: googletrans 3.0.0
#     Uninstalling googletrans-3.0.0:
#       Successfully uninstalled googletrans-3.0.0
# Successfully installed googletrans-4.0.0rc1

# %%
import pandas as pd
data_train = pd.read_csv('/content/drive/MyDrive/Dataset_Indian/Hindi/iitp+-movie-reviews/hi/hi-train.csv')
data_train.head()
# Out:
#   sentiment                                               text
# 0  positive  ’उड़ान’ से विक्रमादित्य\nमोटवाने\nने अच्छे सिन...
# 1   neutral  फिल्म में गानों के दृश्य में अनुष्का को माइक क...
# 2   neutral  फांसी चढ़ने से पहले वह पाकिस्तान के सदर से खास...
# 3  positive  राज कुमार हिरानी ने इस मूवी में भी अपने डायरेक...
# 4  positive  इन फुकरों से आप पहले भी मिल चुके हैं और आपने इ...

# %%
data_test = pd.read_csv('/content/drive/MyDrive/Dataset_Indian/Hindi/iitp+-movie-reviews/hi/hi-test.csv')
data_test.head()
# Out:
#   sentiment                                               text
# 0  negative  निर्माता :\nफरहान अख्तर, रितेश सिधवानी\n\nनिर्...
# 1  positive  असमर्पित रिश्ते में यकीन रखने वाले दोनों मौज-म...
# 2   neutral  बेवकूफियां को हबीब फैज़ल ने लिखा है, जिनका नाम...
# 3   neutral  तब वह मोटी थी और जेरी  ने उस पर ध्यान नहीं दिय...
# 4  positive  'तेवर' में निर्देशक अमित रवींद्रनाथ शर्मा ने अ...

# %%
data_val = pd.read_csv('/content/drive/MyDrive/Dataset_Indian/Hindi/iitp+-movie-reviews/hi/hi-valid.csv')
data_val.head()
# Out:
#   sentiment                                               text
# 0   neutral  निर्माता :\nआदित्य चोपड़ा\n\nनिर्देशक :\nहबीब ...
# 1  positive        इस कसौटी पर करण काफी हद तक खरे भी उतरे हैं।
# 2  positive  छोटे शहर की गालियां, छतें और विहंगम दृश्य मोहक...
# 3  positive        मनीष और जिशान का काम भी लोगों को याद रहेगा।
# 4  positive  बैनर :\nएसएलबी फिल्म्स, हरि ॐ एंटरटेनमेंट कंपन...

# %%
import matplotlib.pyplot as plt
sentiment_counts = data_test['sentiment'].value_counts()
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Sentiment Distribution')
_ = plt.axis('equal')

# %% [markdown]
# ## Data preprocessing

# %%
data_val.isnull().sum()
# Out:
# sentiment    0
# text         0
# dtype: int64

# %%
data_train.shape
# Out:
# (2479, 2)

# %%
data_test.shape
# Out:
# (309, 2)

# %%
data_val.shape
# Out:
# (309, 2)

# %%
import re

def clean_text(text):
    #text = re.sub(r'http\S+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\b[a-zA-Z]\b', " ", text)
    text = re.sub(r"<[^>]*>", " ", text)
    text = text.lower()
    text = re.sub(r'\s+', ' ', text)
    text = text.strip()
    return text

# %%
text = data_train['text'].apply(clean_text)
# text = data_test['text'].apply(clean_text)
# text = data_val['text'].apply(clean_text)

# %%
text = data_test['text'].apply(clean_text)
text = data_val['text'].apply(clean_text)

# %%
data_train
# Out:
#      sentiment                                               text
# 0     positive  ’उड़ान’ से विक्रमादित्य\nमोटवाने\nने अच्छे सिन...
# 1      neutral  फिल्म में गानों के दृश्य में अनुष्का को माइक क...
# 2      neutral  फांसी चढ़ने से पहले वह पाकिस्तान के सदर से खास...
# 3     positive  राज कुमार हिरानी ने इस मूवी में भी अपने डायरेक...
# 4     positive  इन फुकरों से आप पहले भी मिल चुके हैं और आपने इ...
# ...        ...                                                ...
# 2474  positive  प्रकाश झा ने ऐसी फिल्म के निर्माण से सराहनीय क...
# 2475  positive  पता चलता है किअभ्यास और एकाग्रता से कलाकार नए ...
# 2476   neutral     पता चलता है कि वह एक बैंक कर्मचारी की बेटी है।
# 2477  positive           इस बार तो वे अपनी जमीन के किरदार में थे।
# 2478  negative  ढीली पटकथा और कमजोर कहानी की वजह से 'रोर' बांध...
#
# [2479 rows x 2 columns]

# %%
data_test
# Out:
#     sentiment                                               text
# 0    negative  निर्माता :\nफरहान अख्तर, रितेश सिधवानी\n\nनिर्...
# 1    positive  असमर्पित रिश्ते में यकीन रखने वाले दोनों मौज-म...
# 2     neutral  बेवकूफियां को हबीब फैज़ल ने लिखा है, जिनका नाम...
# 3     neutral  तब वह मोटी थी और जेरी  ने उस पर ध्यान नहीं दिय...
# 4    positive  'तेवर' में निर्देशक अमित रवींद्रनाथ शर्मा ने अ...
# ..        ...                                                ...
# 304   neutral      बाकी कलाकार साधारण और स्थानपूर्ति के लिए हैं।
# 305  negative  पिछली कई फिल्मों में स्क्रीन पर दूल्हा बन रहे ...
# 306  positive            अजीत की भूमिका में आनंद तिवारी सहज हैं।
# 307  negative  1983 में आई के राघवेन्द्र राव की हिम्मतवाला की...
# 308   neutral  फिल्म के निर्माता नागेश कुकुनूर और सतीश कौशिक ...
#
# [309 rows x 2 columns]

# %%
data_val
# Out:
#     sentiment                                               text
# 0     neutral  निर्माता :\nआदित्य चोपड़ा\n\nनिर्देशक :\nहबीब ...
# 1    positive        इस कसौटी पर करण काफी हद तक खरे भी उतरे हैं।
# 2    positive  छोटे शहर की गालियां, छतें और विहंगम दृश्य मोहक...
# 3    positive        मनीष और जिशान का काम भी लोगों को याद रहेगा।
# 4    positive  बैनर :\nएसएलबी फिल्म्स, हरि ॐ एंटरटेनमेंट कंपन...
# ..        ...                                                ...
# 304   neutral  निर्देशक फुवाद खान ने भारतीय संदर्भ में यहूदी ...
# 305  positive  तात्पर्य यह कि हिरानी और जोशी की काबिलियत है क...
# 306  positive  सलमान ने एक्शन के दृश्यों में आवश्यक फुर्ती दि...
# 307  positive  फुवाद खान ने सलीके से अपनी बात कही है और किसी ...
# 308   neutral              वे युवा प्रतिभाओं में निवेश करते हैं।
#
# [309 rows x 2 columns]

# %%
data_train['sentiment'].value_counts()
# Out:
# sentiment
# positive    1042
# negative     741
# neutral      696
# Name: count, dtype: int64

# %%
data_train['sentiment'] = data_train['sentiment'].replace({'positive': 1, 'negative': 2, 'neutral': 0})

# %%
data_train
# Out:
#       sentiment                                               text
# 0             1  ’उड़ान’ से विक्रमादित्य\nमोटवाने\nने अच्छे सिन...
# 1             0  फिल्म में गानों के दृश्य में अनुष्का को माइक क...
# 2             0  फांसी चढ़ने से पहले वह पाकिस्तान के सदर से खास...
# 3             1  राज कुमार हिरानी ने इस मूवी में भी अपने डायरेक...
# 4             1  इन फुकरों से आप पहले भी मिल चुके हैं और आपने इ...
# ...         ...                                                ...
# 2474          1  प्रकाश झा ने ऐसी फिल्म के निर्माण से सराहनीय क...
# 2475          1  पता चलता है किअभ्यास और एकाग्रता से कलाकार नए ...
# 2476          0     पता चलता है कि वह एक बैंक कर्मचारी की बेटी है।
# 2477          1           इस बार तो वे अपनी जमीन के किरदार में थे।
# 2478          2  ढीली पटकथा और कमजोर कहानी की वजह से 'रोर' बांध...
#
# [2479 rows x 2 columns]

# %%
data_test['sentiment'].value_counts()
# Out:
# sentiment
# positive    122
# negative     97
# neutral      90
# Name: count, dtype: int64

# %%
data_test['sentiment'] = data_test['sentiment'].replace({'positive': 1, 'negative': 2, 'neutral': 0})

# %%
data_test
# Out:
#      sentiment                                               text
# 0            2  निर्माता :\nफरहान अख्तर, रितेश सिधवानी\n\nनिर्...
# 1            1  असमर्पित रिश्ते में यकीन रखने वाले दोनों मौज-म...
# 2            0  बेवकूफियां को हबीब फैज़ल ने लिखा है, जिनका नाम...
# 3            0  तब वह मोटी थी और जेरी  ने उस पर ध्यान नहीं दिय...
# 4            1  'तेवर' में निर्देशक अमित रवींद्रनाथ शर्मा ने अ...
# ..         ...                                                ...
# 304          0      बाकी कलाकार साधारण और स्थानपूर्ति के लिए हैं।
# 305          2  पिछली कई फिल्मों में स्क्रीन पर दूल्हा बन रहे ...
# 306          1            अजीत की भूमिका में आनंद तिवारी सहज हैं।
# 307          2  1983 में आई के राघवेन्द्र राव की हिम्मतवाला की...
# 308          0  फिल्म के निर्माता नागेश कुकुनूर और सतीश कौशिक ...
#
# [309 rows x 2 columns]

# %%
data_val['sentiment'].value_counts()
# Out:
# sentiment
# positive    121
# negative    108
# neutral      80
# Name: count, dtype: int64

# %%
data_val['sentiment'] = data_val['sentiment'].replace({'positive': 1, 'negative': 2, 'neutral': 0})

# %%
data_val
# Out:
#      sentiment                                               text
# 0            0  निर्माता :\nआदित्य चोपड़ा\n\nनिर्देशक :\nहबीब ...
# 1            1        इस कसौटी पर करण काफी हद तक खरे भी उतरे हैं।
# 2            1  छोटे शहर की गालियां, छतें और विहंगम दृश्य मोहक...
# 3            1        मनीष और जिशान का काम भी लोगों को याद रहेगा।
# 4            1  बैनर :\nएसएलबी फिल्म्स, हरि ॐ एंटरटेनमेंट कंपन...
# ..         ...                                                ...
# 304          0  निर्देशक फुवाद खान ने भारतीय संदर्भ में यहूदी ...
# 305          1  तात्पर्य यह कि हिरानी और जोशी की काबिलियत है क...
# 306          1  सलमान ने एक्शन के दृश्यों में आवश्यक फुर्ती दि...
# 307          1  फुवाद खान ने सलीके से अपनी बात कही है और किसी ...
# 308          0              वे युवा प्रतिभाओं में निवेश करते हैं।
#
# [309 rows x 2 columns]

# %% [markdown]
# ## One shot Learning - Siamese Network

# %% [markdown]
# This approach is used when we have lesser training data, but we want to use this less data to achieve desired results and make sentiment predictions. In this project, we use the One-Shot learning Approach

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from tensorflow.python.keras.models import Model
from keras.layers import BatchNormalization
from tensorflow.python.keras.layers import MaxPooling2D, AveragePooling2D
from tensorflow.python.keras.layers import Concatenate
from keras.layers import Lambda, Flatten, Dense
from keras.initializers import glorot_uniform
import cv2
import os
import numpy as np
from numpy import genfromtxt
import pandas as pd
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.optimizers import Adam
from skimage.io import imshow
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
data_train
# Out:
#       sentiment                                               text
# 0             1  ’उड़ान’ से विक्रमादित्य\nमोटवाने\nने अच्छे सिन...
# 1             0  फिल्म में गानों के दृश्य में अनुष्का को माइक क...
# 2             0  फांसी चढ़ने से पहले वह पाकिस्तान के सदर से खास...
# 3             1  राज कुमार हिरानी ने इस मूवी में भी अपने डायरेक...
# 4             1  इन फुकरों से आप पहले भी मिल चुके हैं और आपने इ...
# ...         ...                                                ...
# 2474          1  प्रकाश झा ने ऐसी फिल्म के निर्माण से सराहनीय क...
# 2475          1  पता चलता है किअभ्यास और एकाग्रता से कलाकार नए ...
# 2476          0     पता चलता है कि वह एक बैंक कर्मचारी की बेटी है।
# 2477          1           इस बार तो वे अपनी जमीन के किरदार में थे।
# 2478          2  ढीली पटकथा और कमजोर कहानी की वजह से 'रोर' बांध...
#
# [2479 rows x 2 columns]

# %%
data_test
# Out:
#      sentiment                                               text
# 0            2  निर्माता :\nफरहान अख्तर, रितेश सिधवानी\n\nनिर्...
# 1            1  असमर्पित रिश्ते में यकीन रखने वाले दोनों मौज-म...
# 2            0  बेवकूफियां को हबीब फैज़ल ने लिखा है, जिनका नाम...
# 3            0  तब वह मोटी थी और जेरी  ने उस पर ध्यान नहीं दिय...
# 4            1  'तेवर' में निर्देशक अमित रवींद्रनाथ शर्मा ने अ...
# ..         ...                                                ...
# 304          0      बाकी कलाकार साधारण और स्थानपूर्ति के लिए हैं।
# 305          2  पिछली कई फिल्मों में स्क्रीन पर दूल्हा बन रहे ...
# 306          1            अजीत की भूमिका में आनंद तिवारी सहज हैं।
# 307          2  1983 में आई के राघवेन्द्र राव की हिम्मतवाला की...
# 308          0  फिल्म के निर्माता नागेश कुकुनूर और सतीश कौशिक ...
#
# [309 rows x 2 columns]

# %%
data_val
# Out:
#      sentiment                                               text
# 0            0  निर्माता :\nआदित्य चोपड़ा\n\nनिर्देशक :\nहबीब ...
# 1            1        इस कसौटी पर करण काफी हद तक खरे भी उतरे हैं।
# 2            1  छोटे शहर की गालियां, छतें और विहंगम दृश्य मोहक...
# 3            1        मनीष और जिशान का काम भी लोगों को याद रहेगा।
# 4            1  बैनर :\nएसएलबी फिल्म्स, हरि ॐ एंटरटेनमेंट कंपन...
# ..         ...                                                ...
# 304          0  निर्देशक फुवाद खान ने भारतीय संदर्भ में यहूदी ...
# 305          1  तात्पर्य यह कि हिरानी और जोशी की काबिलियत है क...
# 306          1  सलमान ने एक्शन के दृश्यों में आवश्यक फुर्ती दि...
# 307          1  फुवाद खान ने सलीके से अपनी बात कही है और किसी ...
# 308          0              वे युवा प्रतिभाओं में निवेश करते हैं।
#
# [309 rows x 2 columns]

# %% [markdown]
# We now define the parameters

# %%
max_voc = 20000
max_len = 100
embedding_dim = 128

# %%
tokenizer = Tokenizer(num_words = max_voc)
tokenizer.fit_on_texts(data_train['text'].tolist())
word_idx = tokenizer.word_index

# %%
train_texts = data_train['text']
train_labels = np.array(data_train['sentiment'])

# %%
test_texts = data_test['text']
test_labels = np.array(data_test['sentiment'])

# %%
val_texts = data_val['text']
val_labels = np.array(data_val['sentiment'])

# %%
def make_pairs(texts, labels):
    pairs = []
    pair_labels = []

    num_classes = len(set(labels))
    class_indices = [np.where(labels == i)[0] for i in range(num_classes)]

    for idx1 in range(len(texts)):
        current_text = texts[idx1]
        label1 = labels[idx1]

        idx2 = np.random.choice(class_indices[label1])
        pos_text = texts[idx2]
        pairs += [[current_text, pos_text]]
        pair_labels += [1]

        neg_label = np.random.choice(list(set(range(num_classes)) - set([label1])))
        idx2 = np.random.choice(class_indices[neg_label])
        neg_text = texts[idx2]
        pairs += [[current_text, neg_text]]
        pair_labels += [0]

    return np.array(pairs), np.array(pair_labels)

# %%
train_pairs, train_pair_labels = make_pairs(train_texts, train_labels)
test_pairs, test_pair_labels = make_pairs(test_texts, test_labels)
val_pairs, val_pair_labels = make_pairs(val_texts, val_labels)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Dropout, Lambda, Bidirectional
from tensorflow.keras.models import Model

# %% [markdown]
# We now define the base LSTM network

# %%
def create_base_network(input_shape):
    input = Input(shape=input_shape)
    x = Embedding(max_voc, embedding_dim, input_length=max_len)(input)
    x = Bidirectional(LSTM(128, return_sequences=True))(x)
    x = Dropout(0.2)(x)
    x = Bidirectional(LSTM(128))(x)
    x = Dropout(0.2)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.2)(x)
    x = Dense(128, activation='relu')(x)
    return Model(input, x)

# %%
input_shape = (max_len,)
base_network = create_base_network(input_shape)

input_a = Input(shape=input_shape)
input_b = Input(shape=input_shape)

processed_a = base_network(input_a)
processed_b = base_network(input_b)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %% [markdown]
# Use L2/euclidean instead of l1_distance

# %%
def l1_distance(vectors):
  x,y = vectors
  return tf.keras.backend.abs(x - y)

# %%
distance = Lambda(l1_distance, output_shape=(128,))([processed_a, processed_b])
outputs = Dense(1, activation='sigmoid')(distance)

# %%
model = Model([input_a, input_b], outputs)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 100)            │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_2             │ (None, 100)            │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ functional (Functional)   │ (None, 128)            │      3,316,096 │ input_layer_1[0][0],   │
# │                           │                        │                │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 128)            │              0 │ functional[0][0],      │
# │                           │                        │                │ functional[1][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 1)              │            129 │ lambda[0][0]           │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 3,316,225 (12.65 MB)
#  Trainable params: 3,316,225 (12.65 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
train_texts_1 = np.array([pair[0] for pair in train_pairs])
train_texts_2 = np.array([pair[1] for pair in train_pairs])

test_texts_1 = np.array([pair[0] for pair in test_pairs])
test_texts_2 = np.array([pair[1] for pair in test_pairs])

val_texts_1 = np.array([pair[0] for pair in val_pairs])
val_texts_2 = np.array([pair[1] for pair in val_pairs])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features=100)

# %%
train_vectors_1 = vectorizer.fit_transform(train_texts_1)
train_vectors_2 = vectorizer.transform(train_texts_2)

test_vectors_1 = vectorizer.transform(test_texts_1)
test_vectors_2 = vectorizer.transform(test_texts_2)

val_vectors_1 = vectorizer.transform(val_texts_1)
val_vectors_2 = vectorizer.transform(val_texts_2)

# %%
history = model.fit([train_vectors_1.toarray(), train_vectors_2.toarray()], train_pair_labels,
                    batch_size=64,
                    epochs=100,
                    validation_data=([val_vectors_1.toarray(), val_vectors_2.toarray()], val_pair_labels))
# Out:
# Epoch 1/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 67ms/step - accuracy: 0.4932 - loss: 0.6941 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 2/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 14s 55ms/step - accuracy: 0.4951 - loss: 0.6939 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 3/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.5025 - loss: 0.6937 - val_accuracy: 0.5032 - val_loss: 0.6931
# Epoch 4/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.5082 - loss: 0.6953 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 5/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.4870 - loss: 0.6960 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 6/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.4861 - loss: 0.7017 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 7/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.4954 - loss: 0.6952 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 8/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.5015 - loss: 0.6956 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 9/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - accuracy: 0.5039 - loss: 0.6939 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 10/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.4990 - loss: 0.6950 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 11/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.5120 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 12/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - accuracy: 0.5025 - loss: 0.6943 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 13/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.5015 - loss: 0.6948 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 14/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.4961 - loss: 0.6949 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 15/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.4916 - loss: 0.6961 - val_accuracy: 0.5016 - val_loss: 0.6931
# Epoch 16/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.4966 - loss: 0.6960 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 17/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.5020 - loss: 0.6937 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 18/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.4881 - loss: 0.6942 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 19/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.5022 - loss: 0.6936 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 20/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.4982 - loss: 0.6943 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 21/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.4943 - loss: 0.6935 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 22/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.5062 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 23/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.5134 - loss: 0.6929 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 24/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.5121 - loss: 0.6943 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 25/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.5059 - loss: 0.6963 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 26/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.5165 - loss: 0.6949 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 27/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.4932 - loss: 0.6943 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 28/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.4943 - loss: 0.6947 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 29/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.5138 - loss: 0.6928 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 30/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.5077 - loss: 0.6944 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 31/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.4992 - loss: 0.6941 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 32/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.4973 - loss: 0.6940 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 33/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.5037 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 34/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.4958 - loss: 0.6941 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 35/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.5016 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 36/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.4936 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 37/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.4774 - loss: 0.6940 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 38/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.4908 - loss: 0.6937 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 39/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.4817 - loss: 0.6940 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 40/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.5006 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 41/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.4941 - loss: 0.6936 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 42/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.4826 - loss: 0.6941 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 43/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.5032 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 44/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.4871 - loss: 0.6942 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 45/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.5026 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 46/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.4933 - loss: 0.6935 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 47/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.4914 - loss: 0.6937 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 48/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.5145 - loss: 0.6927 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 49/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.5102 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 50/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.5068 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 51/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.5064 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 52/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.4995 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 53/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.5048 - loss: 0.6927 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 54/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.4951 - loss: 0.6936 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 55/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.5140 - loss: 0.6928 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 56/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.4926 - loss: 0.6937 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 57/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.4961 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 58/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.5018 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 59/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.4925 - loss: 0.6937 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 60/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.4938 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 61/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.4856 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 62/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.5009 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 63/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.4948 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 64/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.4956 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 65/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.4912 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 66/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.4983 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 67/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.4973 - loss: 0.6935 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 68/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.4962 - loss: 0.6935 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 69/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.4887 - loss: 0.6942 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 70/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.5114 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 71/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.4965 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 72/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.4779 - loss: 0.6943 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 73/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.4990 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 74/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.5002 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 75/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.5005 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 76/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.4810 - loss: 0.6940 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 77/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.5098 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 78/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.4839 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 79/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.5132 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 80/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.4995 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 81/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.4986 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 82/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.4960 - loss: 0.6937 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 83/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.4770 - loss: 0.6941 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 84/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.4925 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 85/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.4881 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 86/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.4944 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 87/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.4903 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 88/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.4782 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 89/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.4972 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 90/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.5024 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 91/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.4854 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 92/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.5003 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 93/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.5057 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 94/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.4793 - loss: 0.6935 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 95/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.4953 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 96/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.5029 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 97/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.4816 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 98/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.5010 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 99/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.5004 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 100/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.5041 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931

# %% [markdown]
# After

# %%
results = model.evaluate([test_vectors_1.toarray(), test_vectors_2.toarray()], test_pair_labels)
print(f'Test Loss: {results[0]}, Test Accuracy: {results[1]}')
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5000 - loss: 0.6931
# Test Loss: 0.6931498050689697, Test Accuracy: 0.5

# %%
def predict_sentiment(sentence, support_texts, support_labels, tokenizer, model):

    sentence_seq = tokenizer.texts_to_sequences([sentence])
    sentence_seq = pad_sequences(sentence_seq, maxlen=100)

    similarities = []
    sentiments = []

    for i in range(len(support_texts)):
        support_sentence = support_texts[i:i+1]
        support_sentence_seq = tokenizer.texts_to_sequences(support_sentence)
        support_sentence_seq = pad_sequences(support_sentence_seq, maxlen=100) # Pad the sequence
        similarity = model.predict([sentence_seq, support_sentence_seq], verbose=0)[0][0]
        similarities.append(similarity)
        sentiments.append(support_labels[i])

    sentiment_score = np.dot(similarities, sentiments) / sum(similarities)
    return 'Positive' if sentiment_score > 0.5 else 'Negative'

# prediction of classes based on whatever is there in user_sentence

from tensorflow.keras.preprocessing.sequence import pad_sequences


user_sentence = "તે એક વાહિયાત જાતિવાદી છે"

support_texts = train_texts[:1000]
support_labels = train_labels[:1000]

predicted_sentiment = predict_sentiment(user_sentence, support_texts, support_labels, tokenizer, model)
print(f'The sentiment of the sentence is: {predicted_sentiment}')
# Out:
# The sentiment of the sentence is: Positive

# %% [markdown]
# Before

# %% [markdown]
# Data Augmentation  - //TODO

# %%
results = model.evaluate([test_vectors_1.toarray(), test_vectors_2.toarray()], test_pair_labels)
print(f'Test Loss: {results[0]}, Test Accuracy: {results[1]}')
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - accuracy: 0.5000 - loss: 0.6932
# Test Loss: 0.6931749582290649, Test Accuracy: 0.5

# %%
def predict_sentiment(sentence, support_texts, support_labels, tokenizer, model):

    sentence_seq = tokenizer.texts_to_sequences([sentence])
    sentence_seq = pad_sequences(sentence_seq, maxlen=100)


    similarities = []
    sentiments = []

    for i in range(len(support_texts)):
        support_sentence = support_texts[i:i+1]
        support_sentence_seq = tokenizer.texts_to_sequences(support_sentence)
        support_sentence_seq = pad_sequences(support_sentence_seq, maxlen=100) # Pad the sequence
        similarity = model.predict([sentence_seq, support_sentence_seq], verbose=0)[0][0]
        similarities.append(similarity)
        sentiments.append(support_labels[i])

    sentiment_score = np.dot(similarities, sentiments) / sum(similarities)

    return 'Positive' if sentiment_score > 0.5 else 'Negative'


from tensorflow.keras.preprocessing.sequence import pad_sequences


user_sentence = "यह एक बहुत अच्छी फिल्म है।"

support_texts = train_texts[:1000]
support_labels = train_labels[:1000]

predicted_sentiment = predict_sentiment(user_sentence, support_texts, support_labels, tokenizer, model)
print(f'The sentiment of the sentence is: {predicted_sentiment}')
# Out:
# The sentiment of the sentence is: Positive

# %% [markdown]
# ### After modification

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Dropout, Lambda, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
data_train = pd.read_csv('/content/drive/MyDrive/Dataset_Indian/Hindi/iitp+-movie-reviews/hi/hi-train.csv')
data_test = pd.read_csv('/content/drive/MyDrive/Dataset_Indian/Hindi/iitp+-movie-reviews/hi/hi-test.csv')
data_val = pd.read_csv('/content/drive/MyDrive/Dataset_Indian/Hindi/iitp+-movie-reviews/hi/hi-valid.csv')

# %%
def clean_text(text):
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\b[a-zA-Z]\b', " ", text)
    text = re.sub(r"<[^>]*>", " ", text)
    text = text.lower()
    text = re.sub(r'\s+', ' ', text)
    text = text.strip()
    return text

data_train['text'] = data_train['text'].apply(clean_text)
data_test['text'] = data_test['text'].apply(clean_text)
data_val['text'] = data_val['text'].apply(clean_text)

# %%
sentiment_mapping = {'positive': 1, 'negative': 2, 'neutral': 0}
data_train['sentiment'] = data_train['sentiment'].map(sentiment_mapping)
data_test['sentiment'] = data_test['sentiment'].map(sentiment_mapping)
data_val['sentiment'] = data_val['sentiment'].map(sentiment_mapping)

# %%
max_voc = 20000
max_len = 100
embedding_dim = 128

# %%
tokenizer = Tokenizer(num_words=max_voc)
tokenizer.fit_on_texts(data_train['text'].tolist())

# %%
train_texts = data_train['text']
train_labels = np.array(data_train['sentiment'])

test_texts = data_test['text']
test_labels = np.array(data_test['sentiment'])

val_texts = data_val['text']
val_labels = np.array(data_val['sentiment'])

# %%
def make_pairs(texts, labels):
    pairs = []
    pair_labels = []
    num_classes = len(set(labels))
    class_indices = [np.where(labels == i)[0] for i in range(num_classes)]

    for idx1 in range(len(texts)):
        current_text = texts[idx1]
        label1 = labels[idx1]

        idx2 = np.random.choice(class_indices[label1])
        pos_text = texts[idx2]
        pairs.append([current_text, pos_text])
        pair_labels.append(1)

        neg_label = np.random.choice(list(set(range(num_classes)) - set([label1])))
        idx2 = np.random.choice(class_indices[neg_label])
        neg_text = texts[idx2]
        pairs.append([current_text, neg_text])
        pair_labels.append(0)

    return np.array(pairs), np.array(pair_labels)

train_pairs, train_pair_labels = make_pairs(train_texts, train_labels)
test_pairs, test_pair_labels = make_pairs(test_texts, test_labels)
val_pairs, val_pair_labels = make_pairs(val_texts, val_labels)

# %%
def create_base_network(input_shape):
    input = Input(shape=input_shape)
    x = Embedding(max_voc, embedding_dim, input_length=max_len)(input)
    x = Bidirectional(LSTM(128, return_sequences=True))(x)
    x = Dropout(0.2)(x)
    x = Bidirectional(LSTM(128))(x)
    x = Dropout(0.2)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.2)(x)
    x = Dense(128, activation='relu')(x)
    return Model(input, x)

# %%
input_shape = (max_len,)
base_network = create_base_network(input_shape)

input_a = Input(shape=input_shape)
input_b = Input(shape=input_shape)

processed_a = base_network(input_a)
processed_b = base_network(input_b)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
def l2_distance(vectors):
    x, y = vectors
    # Compute L2 distance
    euclidean_distance = K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))
    # Divide by 2
    return euclidean_distance / 2.0

# Replace l1_distance with l2_distance
distance = Lambda(l2_distance, output_shape=(1,))([processed_a, processed_b])

# Add a dense layer for the final output
outputs = Dense(1, activation='sigmoid')(distance)

# %%
model = Model([input_a, input_b], outputs)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
train_texts_1 = tokenizer.texts_to_sequences([pair[0] for pair in train_pairs])
train_texts_2 = tokenizer.texts_to_sequences([pair[1] for pair in train_pairs])

test_texts_1 = tokenizer.texts_to_sequences([pair[0] for pair in test_pairs])
test_texts_2 = tokenizer.texts_to_sequences([pair[1] for pair in test_pairs])

val_texts_1 = tokenizer.texts_to_sequences([pair[0] for pair in val_pairs])
val_texts_2 = tokenizer.texts_to_sequences([pair[1] for pair in val_pairs])

train_texts_1 = pad_sequences(train_texts_1, maxlen=max_len)
train_texts_2 = pad_sequences(train_texts_2, maxlen=max_len)

test_texts_1 = pad_sequences(test_texts_1, maxlen=max_len)
test_texts_2 = pad_sequences(test_texts_2, maxlen=max_len)

val_texts_1 = pad_sequences(val_texts_1, maxlen=max_len)
val_texts_2 = pad_sequences(val_texts_2, maxlen=max_len)

# %%
history = model.fit([train_texts_1, train_texts_2], train_pair_labels,
                    batch_size=16,
                    epochs=100,
                    validation_data=([val_texts_1, val_texts_2], val_pair_labels))
# Out:
# Epoch 1/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 22s 52ms/step - accuracy: 0.5015 - loss: 0.6937 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 2/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.5012 - loss: 0.6937 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 3/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.5191 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 4/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.5121 - loss: 0.6928 - val_accuracy: 0.4919 - val_loss: 0.7007
# Epoch 5/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5273 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 6/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4999 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 7/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.5155 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 8/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.4940 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 9/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.4984 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 10/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.5003 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 11/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.4934 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 12/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.5023 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 13/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.4952 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 14/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.4964 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 15/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.5049 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 16/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.4974 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 17/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5001 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 18/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5036 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 19/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4849 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 20/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.4984 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 21/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4988 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 22/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.5049 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 23/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.4976 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 24/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.4932 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 25/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5015 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 26/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5018 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 27/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.4969 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 28/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4960 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 29/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4980 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 30/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.5035 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 31/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.5040 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 32/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5014 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 33/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - accuracy: 0.5108 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 34/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.5005 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 35/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5089 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 36/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.4844 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 37/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4984 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 38/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.5128 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 39/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.4995 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 40/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4985 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 41/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.4994 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 42/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4923 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 43/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5017 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 44/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.4974 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 45/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5062 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 46/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.5032 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 47/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.5029 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 48/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5082 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 49/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5061 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 50/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5113 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 51/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.4948 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 52/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.4970 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 53/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.4963 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 54/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.4988 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 55/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5094 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 56/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.5077 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 57/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.5012 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 58/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5073 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 59/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4910 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 60/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.4891 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 61/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.5061 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 62/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - accuracy: 0.5180 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 63/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.4985 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 64/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4940 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 65/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.5091 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 66/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4995 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 67/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.5001 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 68/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.4949 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 69/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 47ms/step - accuracy: 0.4948 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 70/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5019 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 71/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.4995 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 72/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 47ms/step - accuracy: 0.5095 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 73/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.4967 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 74/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 47ms/step - accuracy: 0.5025 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 75/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 46ms/step - accuracy: 0.4844 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 76/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.5061 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 77/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.4953 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 78/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.4983 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 79/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.5036 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 80/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4976 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 81/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.5000 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 82/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 47ms/step - accuracy: 0.5020 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 83/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4927 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 84/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4996 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 85/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5032 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 86/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5035 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 87/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5099 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 88/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.5138 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 89/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - accuracy: 0.4993 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 90/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 46ms/step - accuracy: 0.4910 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 91/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 47ms/step - accuracy: 0.5036 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 92/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5011 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 93/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4942 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 94/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5126 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 95/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.5017 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 96/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.5008 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 97/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5071 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 98/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 21s 47ms/step - accuracy: 0.4879 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 99/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 46ms/step - accuracy: 0.4960 - loss: nan - val_accuracy: 0.5000 - val_loss: nan
# Epoch 100/100
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5127 - loss: nan - val_accuracy: 0.5000 - val_loss: nan

# %%
results = model.evaluate([test_texts_1, test_texts_2], test_pair_labels)
print(f'Test Loss: {results[0]}, Test Accuracy: {results[1]}')
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5000 - loss: nan
# Test Loss: nan, Test Accuracy: 0.5

# %%
def predict_sentiment(sentence, support_texts, support_labels, tokenizer, model):
    sentence_seq = tokenizer.texts_to_sequences([sentence])
    sentence_seq = pad_sequences(sentence_seq, maxlen=max_len)

    similarities = []
    sentiments = []

    for i in range(len(support_texts)):
        support_sentence = support_texts[i:i+1]
        support_sentence_seq = tokenizer.texts_to_sequences(support_sentence)
        support_sentence_seq = pad_sequences(support_sentence_seq, maxlen=max_len)
        similarity = model.predict([sentence_seq, support_sentence_seq], verbose=0)[0][0]
        similarities.append(similarity)
        sentiments.append(support_labels[i])

    sentiment_score = np.dot(similarities, sentiments) / sum(similarities)
    return 'Positive' if sentiment_score > 0.5 else 'Negative'

# %%
user_sentence = "यह एक बहुत अच्छी फिल्म है।"
support_texts = train_texts[:1000]
support_labels = train_labels[:1000]

predicted_sentiment = predict_sentiment(user_sentence, support_texts, support_labels, tokenizer, model)
print(f'The sentiment of the sentence is: {predicted_sentiment}')
# Out:
# The sentiment of the sentence is: Negative
